# %%
# --- EvaCun Environment bootstrap: run me first ---
# Supports Google Colab, VS Code, and local Jupyter.
import os, sys, subprocess, shutil
from pathlib import Path

# Detect Colab
IN_COLAB = False
try:
    import google.colab  # type: ignore
    IN_COLAB = True
except Exception:
    IN_COLAB = False

# Fork-first strategy:
# Set EVACUN_REPO_URL to your fork, e.g. https://github.com/<your-username>/Akkademia.git
# If left as a placeholder, we'll fall back to upstream.
FORK_PLACEHOLDER = "https://github.com/<your-username>/Akkademia.git"
EVACUN_REPO_URL = os.environ.get("EVACUN_REPO_URL", FORK_PLACEHOLDER).strip()
UPSTREAM_URL = os.environ.get("EVACUN_UPSTREAM_URL", "https://github.com/gaigutherz/Akkademia.git").strip()

repo_url = EVACUN_REPO_URL if "<your-username>" not in EVACUN_REPO_URL else UPSTREAM_URL

# Clone directory name; usually 'Akkademia'
EVACUN_REPO_NAME = os.environ.get("EVACUN_REPO_NAME", "Akkademia")
REPO_DIR = Path(os.getenv("EVACUN_REPO_DIR", Path.cwd() / EVACUN_REPO_NAME)).resolve()

# Data directories
DATA_DIR = REPO_DIR / "data"
DATA_DIR.mkdir(parents=True, exist_ok=True)

# Clone if needed
if not REPO_DIR.exists() or not any(REPO_DIR.iterdir()):
    print(f"Cloning {repo_url} into {REPO_DIR} ...")
    subprocess.check_call(["git", "clone", "--depth", "1", repo_url, str(REPO_DIR)])

# Install project if it has a build file
pyproject = REPO_DIR / "pyproject.toml"
setup_py = REPO_DIR / "setup.py"
if pyproject.exists() or setup_py.exists():
    print("Installing project (editable mode if possible)...")
    try:
        subprocess.check_call([sys.executable, "-m", "pip", "install", "-e", str(REPO_DIR)])
    except subprocess.CalledProcessError:
        print("Editable install failed; falling back to standard install.")
        subprocess.check_call([sys.executable, "-m", "pip", "install", str(REPO_DIR)])

# Add repo to Python path and cd into it
if str(REPO_DIR) not in sys.path:
    sys.path.insert(0, str(REPO_DIR))
os.chdir(REPO_DIR)
print("Working directory set to:", REPO_DIR)
print("EvaCun data directory:", DATA_DIR)

# Optional: install extra deps
for req_name in ["requirements-colab.txt", "requirements.txt"]:
    req_path = REPO_DIR / req_name
    if req_path.exists():
        print(f"Installing dependencies from {req_name} ...")
        try:
            subprocess.check_call([sys.executable, "-m", "pip", "install", "-r", str(req_path)])
        except subprocess.CalledProcessError as e:
            print(f"Warning: Failed to install from {req_name}: {e}")

print("EvaCun bootstrap complete. Replace any old Google Drive paths with INPUT_DIR / OUTPUT_DIR helpers.")

# %%
# --- Path helpers ---
from pathlib import Path
import os

# REPO_DIR and DATA_DIR are defined in the bootstrap cell.
# Recommended: put raw inputs under data/input and outputs under data/outputs
INPUT_DIR = DATA_DIR / "input"
OUTPUT_DIR = DATA_DIR / "outputs"
INPUT_DIR.mkdir(parents=True, exist_ok=True)
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

def in_input(*parts):
    return INPUT_DIR.joinpath(*parts)

def in_output(*parts):
    return OUTPUT_DIR.joinpath(*parts)

print("INPUT_DIR:", INPUT_DIR)
print("OUTPUT_DIR:", OUTPUT_DIR)

# %%
# --- IO helpers ---
import pandas as pd
from pathlib import Path

def read_csv(path, **kwargs):
    path = Path(path)
    print(f"Reading CSV: {path}")
    return pd.read_csv(path, **kwargs)

def write_csv(df, path, **kwargs):
    path = Path(path)
    path.parent.mkdir(parents=True, exist_ok=True)
    print(f"Writing CSV: {path}")
    return df.to_csv(path, index=False, **kwargs)

# %% [markdown]
# #Starting Page
#
# 1. First you will want to add a shortcut for '[Akkadamia-master](https://drive.google.com/drive/folders/11ktSfHQbcjM2uLT2BHHyZyLH0VAw9YNm?usp=drive_link)' to your 'My Drive' folder in Google Drive: https://drive.google.com/drive/folders/11ktSfHQbcjM2uLT2BHHyZyLH0VAw9YNm?usp=drive_link
#
# 2. From there you should be able to mount the notebook and run all following cells. Note that it will overwright the previous instance of any model builds, etc. If you don't want that, you can change the directory paths or download Akkademia-master from GitHub and put it in your folder (then change the directory to reflect the new location).

# %%
# (Disabled) Google Drive mount cell — not needed when running from GitHub.
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## Create a shortcut in your drive to put Akkademia_master in your "MyDrive"

# %%
import pandas as pd
import numpy as np
import os

# %%
# NOTE: Replace absolute Google Drive paths with paths under DATA_DIR / INPUT_DIR / OUTPUT_DIR.
# Example: OLD: '/content/drive/MyDrive/some_folder/file.csv'
#          NEW: in_input('some_folder', 'file.csv')
# (Disabled) Google Drive mount cell — not needed when running from GitHub.
# import sys
# sys.path.append('/content/drive/MyDrive/Akkademia-master/akkadian')
# 
# !pip install sentencepiece
# import sentencepiece
# from pathlib import Path
# import shutil
# Out:
# Collecting sentencepiece
#   Downloading sentencepiece-0.2.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Downloading sentencepiece-0.2.0-cp311-cp311-macosx_11_0_arm64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 17.6 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.2.0

# %% [markdown]
# The following doesn't work because the paths aren't specified correctly. In the tokenization step, we copy + paste code to edit the file paths

# %%
import translation_tokenize as tt
tt.train_tokenizer()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 import translation_tokenize as tt
#       2 tt.train_tokenizer()
#
# ModuleNotFoundError: No module named 'translation_tokenize'

# %% [markdown]
# #I. Data Input Method

# %% [markdown]
# ##1 Read in the CSV data for CDLI and ORACC into a data frame for English.

# %%
clean_oracc_en_path = 'DataFiles/clean_oracc_en.csv'
clean_oracc_en_df = pd.read_csv(clean_oracc_en_path)
clean_oracc_en_df['genre'].fillna("Uncertain", inplace=True)
clean_oracc_en_df
# Out:
#        txt_id  id_text                   Title                  object_type  \
# 0     X150289  X150289  saao-saa15-X150289.txt                     envelope
# 1     X210106  X210106  saao-saa21-X210106.txt                       tablet
# 2     X211891  X211891  saao-saa21-X211891.txt                       tablet
# 3     P237223  P237223       caspo-P237223.txt                          NaN
# 4     P237219  P237219        ccpo-P237219.txt                          NaN
# ...       ...      ...                     ...                          ...
# 8033  Q000960  Q000960      etcsri-Q000960.txt                        brick
# 8034  Q000958  Q000958      etcsri-Q000958.txt                         cone
# 8035  Q000965  Q000965      etcsri-Q000965.txt  canephor, foundation tablet
# 8036  Q000957  Q000957      etcsri-Q000957.txt                         cone
# 8037  Q000962  Q000962      etcsri-Q000962.txt  foundation tablet, canephor
#
#       language        period         dialect                  genre subgenre  \
# 0     Akkadian  Neo-Assyrian    Neo-Assyrian  Administrative Letter      NaN
# 1     Akkadian  Neo-Assyrian  Neo-Babylonian  Administrative Letter      NaN
# 2     Akkadian  Neo-Assyrian    Neo-Assyrian  Administrative Letter      NaN
# 3          NaN           NaN             NaN              Uncertain      NaN
# 4          NaN           NaN             NaN              Uncertain      NaN
# ...        ...           ...             ...                    ...      ...
# 8033  Sumerian        Ur III             NaN      Royal Inscription      NaN
# 8034  Sumerian        Ur III             NaN      Royal Inscription      NaN
# 8035  Sumerian        Ur III             NaN      Royal Inscription      NaN
# 8036  Sumerian        Ur III             NaN      Royal Inscription      NaN
# 8037  Sumerian        Ur III             NaN      Royal Inscription      NaN
#
#                                                 English  \
# 0       to the deputy governor  my lord  seal impres...
# 1       the king s word to hundaru  king of dilmun  ...
# 2         i went to my        and appealed to assurb...
# 3           of the goddesses      of the world      ...
# 4         means     it rains and the rainbow arches ...
# ...                                                 ...
# 8033    šulgi  the powerful man  king of urim  king ...
# 8034    for nanna  his master  ur namma  the powerfu...
# 8035    for ninĝirsu  the powerful warrior of enlil ...
# 8036    for enlil  king of all lands  his master  ur...
# 8037    for inana  the lady of the e ana  his lady  ...
#
#                                        Original_GS_Text
# 0     (1) [To the deputy (governor)], my lord: (seal...
# 1     (1) The king's word to Hunda[ru, king of Dilmu...
# 2      (Beginning destroyed)(1') I went [to] my [......
# 3     [. . .] of the goddesses[. . .] of the world[....
# 4     [... means ...] it rains and (the rainbow) arc...
# ...                                                 ...
# 8033  (1) Šulgi, the powerful man, king of Urim, kin...
# 8034  (1) For Nanna, his master, Ur-Namma, the power...
# 8035  (1) For Ninĝirsu, the powerful warrior of Enli...
# 8036  (1) For Enlil, king of all lands, his master, ...
# 8037  (1) For Inana, the lady of the E-ana, his lady...
#
# [8038 rows x 11 columns]

# %%
nan_count = clean_oracc_en_df['genre'].isna().sum() #466
unique_genres = clean_oracc_en_df['genre'].unique()
unique_genres
# Out:
# array(['Administrative Letter', 'Uncertain', 'Grant', 'Decree',
#        'Astrological Report', 'Literary Work', 'Extispicy Query',
#        'Extispicy Report', 'Administrative Record', 'Scholarly Letter',
#        'Legal Transaction', 'Prophecy', 'Appointment', 'Priestly Letter',
#        'Royal Ritual', 'Votive Donation', 'Eponym List', 'Treaty', 'Gift',
#        'School Text', 'Lexical Text', 'Astronomical Diary',
#        'Royal Inscription', 'Blessings', 'letter'], dtype=object)

# %% [markdown]
# ##2 Split the data into 80 / 10 / 10 and save to files: .tr / .en / .ak

# %%
training_genres = ['Extispicy Report', 'Grant', 'Royal Ritual', 'Literary Work', 'Uncertain',
                    'Decree', 'Treaty', 'Prophecy', 'Votive Donation', 'Appointment', 'Eponym List',
                    'Lexical Text', 'Gift', 'Blessings', 'School Text']

specified_rows = clean_oracc_en_df[clean_oracc_en_df['genre'].isin(training_genres)]
rows_needed = int(len(clean_oracc_en_df) * 0.8) - len(specified_rows)
remaining_rows = clean_oracc_en_df[~clean_oracc_en_df.index.isin(specified_rows.index)]
additional_rows = remaining_rows.sample(n=rows_needed, random_state=30)
training = pd.concat([specified_rows.copy(), additional_rows])
training['English'] #This is the DataFrame with 80% of the rows; 8038 x 0.8 = 6430
# Out:
# 3             of the goddesses      of the world      ...
# 4           means     it rains and the rainbow arches ...
# 5                              house  šà means  center...
# 6                      sin of the gods  whose face is ...
# 7                    the bišši plant  mustard         ...
#                               ...
# 1280               any human being  whether male or fe...
# 6624      itur ilum  governor of babylon  iṣur ilum  t...
# 4941      seal of arbailāya   seal of mutakkil aššur  ...
# 7381      to          dedicated this object for his ow...
# 4453      if on the 14th day the moon and sun are seen...
# Name: English, Length: 6430, dtype: object

# %%
testing_and_validation = clean_oracc_en_df[~clean_oracc_en_df.index.isin(training.index)]
testing = testing_and_validation.sample(frac=0.5, random_state=30)
validation = testing_and_validation.drop(testing.index)
#testing.head(10)
#validation.head(10)
testing_and_validation.head(10)
# Out:
#       txt_id  id_text                   Title object_type  language  \
# 0    X150289  X150289  saao-saa15-X150289.txt    envelope  Akkadian
# 2    X211891  X211891  saao-saa21-X211891.txt      tablet  Akkadian
# 301  P336327  P336327  saao-saa04-P336327.txt      tablet  Akkadian
# 306  P336340  P336340  saao-saa04-P336340.txt      tablet  Akkadian
# 307  P336341  P336341  saao-saa04-P336341.txt      tablet  Akkadian
# 331  P336368  P336368  saao-saa07-P336368.txt      tablet  Akkadian
# 341  P336378  P336378  saao-saa08-P336378.txt      tablet  Akkadian
# 343  P336381  P336381  saao-saa08-P336381.txt      tablet  Akkadian
# 348  P336386  P336386  saao-saa08-P336386.txt      tablet  Akkadian
# 350  P336388  P336388  saao-saa08-P336388.txt      tablet  Akkadian
#
#            period         dialect                  genre  \
# 0    Neo-Assyrian    Neo-Assyrian  Administrative Letter
# 2    Neo-Assyrian    Neo-Assyrian  Administrative Letter
# 301  Neo-Assyrian  Neo-Babylonian        Extispicy Query
# 306  Neo-Assyrian  Neo-Babylonian        Extispicy Query
# 307  Neo-Assyrian  Neo-Babylonian        Extispicy Query
# 331  Neo-Assyrian             NaN  Administrative Record
# 341  Neo-Assyrian    Neo-Assyrian    Astrological Report
# 343  Neo-Assyrian  Neo-Babylonian    Astrological Report
# 348  Neo-Assyrian    Neo-Assyrian    Astrological Report
# 350  Neo-Assyrian    Neo-Assyrian    Astrological Report
#
#                    subgenre  \
# 0                       NaN
# 2                       NaN
# 301  military and political
# 306  military and political
# 307  military and political
# 331                     NaN
# 341               planetary
# 343          unclassifiable
# 348                   lunar
# 350                   lunar
#
#                                                English  \
# 0      to the deputy governor  my lord  seal impres...
# 2        i went to my        and appealed to assurb...
# 301    šamaš  great lord  give me a firm positive a...
# 306      will they do battle          is it decreed...
# 307    šamaš  great lord  give me a firm positive a...
# 331    a thigh  a shoulder  outer cuts   2 cuts of ...
# 341    if the moon becomes visible on the 1st day  ...
# 343    if the moon at its appearance wears a crown ...
# 348    if the moon becomes visible on the 1st day  ...
# 350    if the moon at its appearance wears a crown ...
#
#                                       Original_GS_Text
# 0    (1) [To the deputy (governor)], my lord: (seal...
# 2     (Beginning destroyed)(1') I went [to] my [......
# 301  (1) Šamaš, great lord, [give me a firm positiv...
# 306   (Beginning destroyed)(2) will they do [battle...
# 307  (1) Šamaš, great lord, [give me a firm positiv...
# 331  (1) A thigh, a shoulder, outer cuts;(2) 2 cuts...
# 341  (1) If the moon becomes visible on the 1st day...
# 343  (1) If the moon at its appearance wears a crow...
# 348  (1) [If] the moon becomes visible on the 1st d...
# 350  (1) [If the moon] at its appearance wears a cr...

# %% [markdown]
# ##3 Do the same for transliteration and Akkadian and then save files to NMT_input
#
# Path("/content/drive/MyDrive/Akkademia-master/NMT_input")

# %%
akk_tr_cun_path = 'DataFiles/akk_tr_cun.csv'
akk_tr_cun_df = pd.read_csv(akk_tr_cun_path)
pd.set_option('display.max_columns', 1000)
# Out:
# /var/folders/1z/rkrm8_xn3032mzm7dfffywjc0000gn/T/ipykernel_46791/3115568467.py:2: DtypeWarning: Columns (14,15,16,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   akk_tr_cun_df = pd.read_csv(akk_tr_cun_path)

# %%
aligned = pd.merge(akk_tr_cun_df, clean_oracc_en_df, on='id_text', how='inner')
aligned
# Out:
#         Unnamed: 0          lang           form       id_word label  id_text  \
# 0               18  akk-x-neoass            1/2   P522597.2.1   o 1  P522597
# 1               19  akk-x-neoass          MA.NA   P522597.2.2   o 1  P522597
# 2               20  akk-x-neoass     KU₃.BABBAR   P522597.2.3   o 1  P522597
# 3               21  akk-x-neoass            ša₂   P522597.3.1   o 2  P522597
# 4               22  akk-x-neoass  {m}ha-an-ni-i   P522597.3.2   o 2  P522597
# ...            ...           ...            ...           ...   ...      ...
# 759148     2736265  akk-x-neobab              x  P313663.14.5   13'  P313663
# 759149     2736266  akk-x-neobab              x  P313663.14.6   13'  P313663
# 759150     2736267  akk-x-neobab              x  P313663.14.7   13'  P313663
# 759151     2736268  akk-x-neobab              x  P313663.14.8   13'  P313663
# 759152     2736269  akk-x-neobab              x  P313663.14.9   13'  P313663
#
#         delim                                                gdl  pos     cf  \
# 0         NaN  [{'n': 'n', 'sexified': '1/2(disz)', 'form': '...    n    NaN
# 1         NaN  [{'gg': 'logo', 'gdl_type': 'logo', 'group': [...    N   manû
# 2         NaN  [{'gg': 'logo', 'gdl_type': 'logo', 'group': [...    N  ṣarpu
# 3         NaN              [{'v': 'ša₂', 'id': 'P522597.3.1.0'}]  DET     ša
# 4         NaN  [{'det': 'semantic', 'pos': 'pre', 'seq': [{'v...   PN  Hanni
# ...       ...                                                ...  ...    ...
# 759148    NaN  [{'v': 'x', 'utf8': 'x', 'id': 'P313663.14.5.0...    u    NaN
# 759149    NaN  [{'v': 'x', 'utf8': 'x', 'id': 'P313663.14.6.0...    u    NaN
# 759150    NaN  [{'v': 'x', 'utf8': 'x', 'id': 'P313663.14.7.0...    u    NaN
# 759151    NaN  [{'v': 'x', 'utf8': 'x', 'id': 'P313663.14.8.0...    u    NaN
# 759152    NaN  [{'v': 'x', 'utf8': 'x', 'id': 'P313663.14.9.0...    u    NaN
#
#             gw             sense   norm epos headform contrefs norm0 base  \
# 0          NaN               NaN    NaN  NaN      NaN      NaN   NaN  NaN
# 1         unit  a unit of weight   manā    N      NaN      NaN   NaN  NaN
# 2       silver            silver  ṣarpu    N      NaN      NaN   NaN  NaN
# 3           of                of     ša  DET      NaN      NaN   NaN  NaN
# 4            1                 1  Hanni   PN      NaN      NaN   NaN  NaN
# ...        ...               ...    ...  ...      ...      ...   ...  ...
# 759148     NaN               NaN    NaN  NaN      NaN      NaN   NaN  NaN
# 759149     NaN               NaN    NaN  NaN      NaN      NaN   NaN  NaN
# 759150     NaN               NaN    NaN  NaN      NaN      NaN   NaN  NaN
# 759151     NaN               NaN    NaN  NaN      NaN      NaN   NaN  NaN
# 759152     NaN               NaN    NaN  NaN      NaN      NaN   NaN  NaN
#
#        morph stem  cont  syntax_ub-after  morph2  aform    id_line  \
# 0        NaN  NaN   NaN              NaN     NaN    NaN  P522597.1
# 1        NaN  NaN   NaN              NaN     NaN    NaN  P522597.2
# 2        NaN  NaN   NaN              NaN     NaN    NaN  P522597.3
# 3        NaN  NaN   NaN              NaN     NaN    NaN  P522597.1
# 4        NaN  NaN   NaN              NaN     NaN    NaN  P522597.2
# ...      ...  ...   ...              ...     ...    ...        ...
# 759148   NaN  NaN   NaN              NaN     NaN    NaN  P313663.5
# 759149   NaN  NaN   NaN              NaN     NaN    NaN  P313663.6
# 759150   NaN  NaN   NaN              NaN     NaN    NaN  P313663.7
# 759151   NaN  NaN   NaN              NaN     NaN    NaN  P313663.8
# 759152   NaN  NaN   NaN              NaN     NaN    NaN  P313663.9
#
#         form_stripped unicode_stripped        unicode  roman   txt_id  \
# 0                 1/2                𒈦              𒈦  False  P522597
# 1               MA NA              𒈠 𒈾          ma.na  False  P522597
# 2          KU₃ BABBAR              𒆬 𒌓     ku₃.babbar  False  P522597
# 3                 ša₂                𒃻              𒃻  False  P522597
# 4        m ha an ni i        𒁹 𒄩 𒀭 𒉌 𒄿  {m}ha-an-ni-i  False  P522597
# ...               ...              ...            ...    ...      ...
# 759148                             NaN            NaN  False  P313663
# 759149                             NaN            NaN  False  P313663
# 759150                             NaN            NaN  False  P313663
# 759151                             NaN            NaN  False  P313663
# 759152                             NaN            NaN  False  P313663
#
#                              Title object_type  language        period  \
# 0       atae-tilbarsip-P522597.txt      tablet  Akkadian  Neo-Assyrian
# 1       atae-tilbarsip-P522597.txt      tablet  Akkadian  Neo-Assyrian
# 2       atae-tilbarsip-P522597.txt      tablet  Akkadian  Neo-Assyrian
# 3       atae-tilbarsip-P522597.txt      tablet  Akkadian  Neo-Assyrian
# 4       atae-tilbarsip-P522597.txt      tablet  Akkadian  Neo-Assyrian
# ...                            ...         ...       ...           ...
# 759148      saao-saa21-P313663.txt      tablet  Akkadian  Neo-Assyrian
# 759149      saao-saa21-P313663.txt      tablet  Akkadian  Neo-Assyrian
# 759150      saao-saa21-P313663.txt      tablet  Akkadian  Neo-Assyrian
# 759151      saao-saa21-P313663.txt      tablet  Akkadian  Neo-Assyrian
# 759152      saao-saa21-P313663.txt      tablet  Akkadian  Neo-Assyrian
#
#                dialect                  genre            subgenre  \
# 0         Neo-Assyrian      Legal Transaction  debt note (silver)
# 1         Neo-Assyrian      Legal Transaction  debt note (silver)
# 2         Neo-Assyrian      Legal Transaction  debt note (silver)
# 3         Neo-Assyrian      Legal Transaction  debt note (silver)
# 4         Neo-Assyrian      Legal Transaction  debt note (silver)
# ...                ...                    ...                 ...
# 759148  Neo-Babylonian  Administrative Letter                 NaN
# 759149  Neo-Babylonian  Administrative Letter                 NaN
# 759150  Neo-Babylonian  Administrative Letter                 NaN
# 759151  Neo-Babylonian  Administrative Letter                 NaN
# 759152  Neo-Babylonian  Administrative Letter                 NaN
#
#                                                   English  \
# 0         half a mina of silver belonging to hanni  at...
# 1         half a mina of silver belonging to hanni  at...
# 2         half a mina of silver belonging to hanni  at...
# 3         half a mina of silver belonging to hanni  at...
# 4         half a mina of silver belonging to hanni  at...
# ...                                                   ...
# 759148      did he return this statue      in which   ...
# 759149      did he return this statue      in which   ...
# 759150      did he return this statue      in which   ...
# 759151      did he return this statue      in which   ...
# 759152      did he return this statue      in which   ...
#
#                                          Original_GS_Text
# 0       (1) Half a mina of silver belonging to Hanni, ...
# 1       (1) Half a mina of silver belonging to Hanni, ...
# 2       (1) Half a mina of silver belonging to Hanni, ...
# 3       (1) Half a mina of silver belonging to Hanni, ...
# 4       (1) Half a mina of silver belonging to Hanni, ...
# ...                                                   ...
# 759148   (Beginning destroyed)(1') Did he retur[n] thi...
# 759149   (Beginning destroyed)(1') Did he retur[n] thi...
# 759150   (Beginning destroyed)(1') Did he retur[n] thi...
# 759151   (Beginning destroyed)(1') Did he retur[n] thi...
# 759152   (Beginning destroyed)(1') Did he retur[n] thi...
#
# [759153 rows x 39 columns]

# %%
akk_tr_cun_df['form'].head(10)
# Out:
# 0                1/2
# 1              MA.NA
# 2         KU₃.BABBAR
# 3                ša₂
# 4      {m}ha-an-ni-i
# 5                ina
# 6                IGI
# 7    {m}DINGIR-ba-di
# 8                ina
# 9                IGI
# Name: form, dtype: object

# %%
aggregation_functions = {
    'unicode_stripped': lambda x: ' '.join(x.fillna('').astype(str)),
    'form': lambda x: ' '.join(x.fillna('').astype(str)),
    'English': 'first'
}

aligned_unique = aligned.groupby('id_text').agg(aggregation_functions).reset_index()
aligned_unique
# Out:
#       id_text                                   unicode_stripped  \
# 0     P223388  𒌋𒌋 𒉡 𒁹 𒃻 𒋫 𒆸 𒌑 𒇻 𒋫 𒆸 𒀀 𒉌 𒉡 𒀀 𒈾 𒀭 𒀝 𒋳 𒆷 𒀀 𒉌 𒀀 𒈾...
# 1     P224946  𒉌𒌓 𒈩 𒁹 𒄩 𒆷 𒁉 𒂊 𒋛 𒇽 𒌣 𒍏 𒀀 𒁹 𒅋 𒆷 𒀀 𒀀 𒂗 𒊩 𒋧 𒀀 𒉌 𒊩...
# 2     P224947  +   𒆬 𒌓 + 𒊭 𒁹 𒀭 𒈦 𒌋𒌋 𒉽 𒀸 𒅆 𒁹 𒋢 𒌋𒐊 𒌉 𒁹 𒋢 𒌋 𒀀 𒀸 ...
# 3     P224948  𒉌𒌓 𒈩 𒁹 𒀭 𒆷 𒋢 𒀀 𒁹 𒀀 𒉣 𒅀 𒀀 𒌋 𒋫 𒊮 𒌷 𒍝 𒀭 𒁀 𒀀 𒀀 220...
# 4     P224949  𒉌𒌓 𒈩 𒁹 𒀴 𒀭 𒉺 𒌉 𒁹 𒀊 𒁲 𒀭 𒆳 𒀀 𒐋 𒂆 𒆬 𒌓 𒊭 𒁹 𒀭 𒈦 𒌋𒌋 ...
# ...       ...                                                ...
# 5505  X301613   𒁹 𒉏 𒁺     𒁺 𒈪 𒑑 𒌍 𒀸 𒅆 𒋼   𒁺 𒈪 𒑔 𒊕 𒈪 𒌍 𒀸 𒅆 𒋼 𒌓...
# 5506  X301620  𒈬 𒁹 𒈨 𒐏𒑆 𒄰 𒁹 𒀭 𒈗 𒉈 𒌍 𒌋 𒍑 𒈾 𒋢 𒈠 𒁹 𒋝 𒀀 𒆚 𒈲 𒈪 𒈫 𒌍...
# 5507  X301631  𒌗 𒄞 𒌍 𒌋𒐈 𒈾 𒋢 𒋛𒀀 𒈲 𒋛𒀀 𒀭 𒍝     𒌍 𒀸 𒅆 𒄞 𒌓   𒁹 𒋙 𒁺...
# 5508  X301632  𒀳  𒋛𒀀 𒀭 𒍝 𒍇 𒌋 𒆳 𒁺 𒈨𒌍 𒁹 𒋛𒀀   𒈪 𒑑 𒌍 𒂊 𒀸 𒁁 𒈫 𒌑 𒌍 ...
# 5509  X301633       𒀭 𒍝 𒋛 𒁺 𒈪 𒌋𒐋 𒀸 𒂟 𒌍 𒌒 𒈦 𒈦 𒃻 𒉺𒇻     𒅔 𒌋𒐍 𒄞 ...
#
#                                                    form  \
# 0     man-nu ana ša₂ ta-kil-u₂ lu ta-kil a-ni-nu a-n...
# 1     {NA₄}KIŠIB {1}ha-la-be₂-e-si {LU₂}SIMUG-URUDU ...
# 2     x+x x x KUG.UD x+x ša {1}{d}MAŠ-MAN-PAB ina IG...
# 3     {na₄}KIŠIB {m}DINGIR-la-SU A {m}a-ṣil-ia-a-u T...
# 4     {NA₄}KIŠIB {1}ARAD-{d}PA DUMU {1}ab-di-{d}kur-...
# ...                                                 ...
# 5505  x ana NIM GUB x x x x GIN GE₆ 3 sin ina IGI MU...
# 5506  MU 1 ME 49.KAM {m}an LUGAL NE 30 10 UŠ na-su m...
# 5507  {ITU}GU₄ 30 13 na-su DIR muš DIR AN ZA x x x x...
# 5508  APIN x DIR AN ZA ULU₃ u KUR GIN{MEŠ} 1 DIR x x...
# 5509  x x x x x AN ZA SI GIN GE₆ 16 ina ZALAG₂ sin a...
#
#                                                 English
# 0       may anyone trust in whomever he trusts  as f...
# 1       seal of hallabeše  copper smith  son of illa...
# 2           silver belonging to inurta šarru uṣur  a...
# 3       seal of ila eriba  son of aṣil iau  from the...
# 4       seal of urdu nabû  son of abdi kura   6 shek...
# ...                                                 ...
# 5505        stood to the east                  blew ...
# 5506    year 149  king antiochus  month v  the 1st o...
# 5507    month ii  the 1st of which was identical wit...
# 5508    month viii      clouds were in the sky  the ...
# 5509                     were in the sky  the north ...
#
# [5510 rows x 4 columns]

# %%
# !pip install sklearn.utils
from sklearn.model_selection import train_test_split

training_akk, temp_df = train_test_split(aligned_unique['unicode_stripped'], test_size=0.2, random_state=30)

testing_akk, validation_akk = train_test_split(temp_df, test_size=0.5, random_state=30)

training_akk = training_akk.to_frame()
testing_akk = testing_akk.to_frame()
validation_akk = validation_akk.to_frame()
#training_akk.head(30)

training_tr, temp_df2 = train_test_split(aligned_unique['form'], test_size=0.2, random_state=30)

testing_tr, validation_tr = train_test_split(temp_df2, test_size=0.5, random_state=30)

training_tr = training_tr.to_frame()
testing_tr = testing_tr.to_frame()
validation_tr = validation_tr.to_frame()
# Out:
# Collecting sklearn.utils
#   Downloading sklearn_utils-0.0.15.tar.gz (26 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from sklearn.utils) (1.25.2)
# Collecting pyfunctional (from sklearn.utils)
#   Downloading pyfunctional-1.5.0-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from sklearn.utils) (2.0.3)
# Collecting scipy (from sklearn.utils)
#   Downloading scipy-1.14.1-cp311-cp311-macosx_14_0_arm64.whl.metadata (60 kB)
# Collecting scikit-learn (from sklearn.utils)
#   Downloading scikit_learn-1.5.1-cp311-cp311-macosx_12_0_arm64.whl.metadata (12 kB)
# Collecting statsmodels (from sklearn.utils)
#   Downloading statsmodels-0.14.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Collecting seaborn (from sklearn.utils)
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->sklearn.utils) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->sklearn.utils) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->sklearn.utils) (2023.3)
# Collecting dill>=0.2.5 (from pyfunctional->sklearn.utils)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting tabulate<=1.0.0 (from pyfunctional->sklearn.utils)
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting joblib>=1.2.0 (from scikit-learn->sklearn.utils)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->sklearn.utils)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting matplotlib!=3.6.1,>=3.4 (from seaborn->sklearn.utils)
#   Downloading matplotlib-3.9.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting patsy>=0.5.6 (from statsmodels->sklearn.utils)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: packaging>=21.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from statsmodels->sklearn.utils) (24.1)
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.4->seaborn->sklearn.utils)
#   Downloading contourpy-1.3.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.4->seaborn->sklearn.utils)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.6.1,>=3.4->seaborn->sklearn.utils)
#   Downloading fonttools-4.53.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (162 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn->sklearn.utils)
#   Downloading kiwisolver-1.4.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Collecting pillow>=8 (from matplotlib!=3.6.1,>=3.4->seaborn->sklearn.utils)
#   Downloading pillow-10.4.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn->sklearn.utils)
#   Downloading pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from patsy>=0.5.6->statsmodels->sklearn.utils) (1.16.0)
# Downloading pyfunctional-1.5.0-py3-none-any.whl (53 kB)
# Downloading scikit_learn-1.5.1-cp311-cp311-macosx_12_0_arm64.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 16.9 MB/s eta 0:00:00a 0:00:01
# Downloading scipy-1.14.1-cp311-cp311-macosx_14_0_arm64.whl (23.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 18.5 MB/s eta 0:00:0000:0100:01
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading statsmodels-0.14.2-cp311-cp311-macosx_11_0_arm64.whl (10.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 17.3 MB/s eta 0:00:00 0:00:01
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading matplotlib-3.9.2-cp311-cp311-macosx_11_0_arm64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 15.9 MB/s eta 0:00:00a 0:00:01
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading contourpy-1.3.0-cp311-cp311-macosx_11_0_arm64.whl (250 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.53.1-cp311-cp311-macosx_11_0_arm64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 18.7 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp311-cp311-macosx_11_0_arm64.whl (66 kB)
# Downloading pillow-10.4.0-cp311-cp311-macosx_11_0_arm64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 18.6 MB/s eta 0:00:00
# Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
# Building wheels for collected packages: sklearn.utils
#   Building wheel for sklearn.utils (pyproject.toml) ... done
#   Created wheel for sklearn.utils: filename=sklearn_utils-0.0.15-py3-none-any.whl size=27870 sha256=20dcb4e601c0aedc0a3350dd5fdf7fc336f4b87182ddb74af471cf35425ae63f
#   Stored in directory: /Users/christiankarren/Library/Caches/pip/wheels/f8/a5/9a/9443f3739050308de4d75fea8a443bf1070639a46ec0ce648a
# Successfully built sklearn.utils
# Installing collected packages: threadpoolctl, tabulate, scipy, pyparsing, pillow, patsy, kiwisolver, joblib, fonttools, dill, cycler, contourpy, scikit-learn, pyfunctional, matplotlib, statsmodels, seaborn, sklearn.utils
# Successfully installed contourpy-1.3.0 cycler-0.12.1 dill-0.3.8 fonttools-4.53.1 joblib-1.4.2 kiwisolver-1.4.5 matplotlib-3.9.2 patsy-0.5.6 pillow-10.4.0 pyfunctional-1.5.0 pyparsing-3.1.4 scikit-learn-1.5.1 scipy-1.14.1 seaborn-0.13.2 sklearn.utils-0.0.15 statsmodels-0.14.2 tabulate-0.9.0 threadpoolctl-3.5.0

# %%
def save_df_to_file(df, filename):
  folder_path = 'DataFiles/NMT_input/'
  with open(f'{folder_path}{filename}', 'w') as f:
        for index, row in df.iterrows():
            f.write(' '.join(str(value) for value in row) + '\n')

save_df_to_file(training, 'train.en')
save_df_to_file(testing, 'test.en')
save_df_to_file(validation, 'valid.en')
save_df_to_file(training_akk, 'train.ak')
save_df_to_file(testing_akk, 'test.ak')
save_df_to_file(validation_akk, 'valid.ak')
save_df_to_file(training_tr, 'train.tr')
save_df_to_file(testing_tr, 'test.tr')
save_df_to_file(validation_tr, 'valid.tr')

# %% [markdown]
# #II. Tokenization:

# %% [markdown]
# ##1. I copy in the intialization steps and the functions train_and_move and train_tokenizer. I also edited the paths in order for the functions to run properly.

# %%
# NOTE: Replace absolute Google Drive paths with paths under DATA_DIR / INPUT_DIR / OUTPUT_DIR.
# Example: OLD: '/content/drive/MyDrive/some_folder/file.csv'
#          NEW: in_input('some_folder', 'file.csv')
# (Disabled) Google Drive mount cell — not needed when running from GitHub.
# BASE_DIR = Path("../NMT_input") / Path("not_divided_by_three_dots")
# 
# DIVIDED_BY_THREE_DOTS = False
# 
# if DIVIDED_BY_THREE_DOTS == True:
#     BASE_DIR = Path("DataFiles/NMT_input/") #Christian & Adam
# #   BASE_DIR = Path("/content/drive/MyDrive/Akkademia-master/NMT_input") #update the path when connected
# else:
# #   BASE_DIR = Path("/content/drive/MyDrive/Akkademia-master/NMT_input") / Path("not_divided_by_three_dots")
#     BASE_DIR = Path("DataFiles/NMT_input/") #Christian & Adam
# 
# TOKEN_DIR = BASE_DIR / Path("tokenization")
# 
# TRAIN_AK = Path("train.ak")
# TRAIN_TR = Path("train.tr")
# TRAIN_EN = Path("train.en")
# VALID_AK = Path("valid.ak")
# VALID_TR = Path("valid.tr")
# VALID_EN = Path("valid.en")
# TEST_AK = Path("test.ak")
# TEST_TR = Path("test.tr")
# TEST_EN = Path("test.en")
# FOR_TRANSLATION_TR = Path("for_translation.tr")
# 
# 
# def train_and_move(input_file, model_type, model_prefix, vocab_size):
#     sentencepiece.SentencePieceTrainer.train(f'--input={input_file} --model_type={model_type} --model_prefix={model_prefix} --vocab_size={vocab_size}')
# 
#     f = model_prefix + ".model"
#     shutil.move(f, TOKEN_DIR / f)
#     f = model_prefix + ".vocab"
#     shutil.move(f, TOKEN_DIR / f)
#     print('done')
# 
# 
# def train_tokenizer():
#     train_and_move(BASE_DIR / TRAIN_AK, "char", "signs_char", 400)
#     # train_and_move(BASE_DIR / TRAIN_AK, "bpe", "signs_bpe", 400)
#     train_and_move(BASE_DIR / TRAIN_TR, "bpe", "transliteration_bpe", 1000)
#     train_and_move(BASE_DIR / TRAIN_EN, "bpe", "translation_bpe", 10000)

# %%
train_and_move(BASE_DIR / TRAIN_AK, "char", "my_signs_char", 400)
# Out:
# done
# sentencepiece_trainer.cc(178) LOG(INFO) Running command: --input=DataFiles/NMT_input/train.ak --model_type=char --model_prefix=my_signs_char --vocab_size=400
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: DataFiles/NMT_input/train.ak
#   input_format:
#   model_prefix: my_signs_char
#   model_type: CHAR
#   vocab_size: 400
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(353) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(185) LOG(INFO) Loading corpus: DataFiles/NMT_input/train.ak
# trainer_interface.cc(380) LOG(WARNING) Found too long line (14564 > 4192).
# trainer_interface.cc(382) LOG(WARNING) Too long lines are skipped in the training.
# trainer_interface.cc(383) LOG(WARNING) The maximum length can be changed with --max_sentence_length=<size> flag.
# trainer_interface.cc(409) LOG(INFO) Loaded all 4278 sentences
# trainer_interface.cc(416) LOG(INFO) Skipped 130 too long sentences.
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(430) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(539) LOG(INFO) all chars count=1292284
# trainer_interface.cc(550) LOG(INFO) Done: 99.9503% characters are covered.
# trainer_interface.cc(560) LOG(INFO) Alphabet size=324
# trainer_interface.cc(561) LOG(INFO) Final character coverage=0.999503
# trainer_interface.cc(592) LOG(INFO) Done! preprocessed 4276 sentences.
# trainer_interface.cc(687) LOG(INFO) Saving model: my_signs_char.model
# trainer_interface.cc(699) LOG(INFO) Saving vocabs: my_signs_char.vocab

# %%
train_tokenizer()
# Out:
# sentencepiece_trainer.cc(178) LOG(INFO) Running command: --input=DataFiles/NMT_input/train.ak --model_type=char --model_prefix=signs_char --vocab_size=400
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: DataFiles/NMT_input/train.ak
#   input_format:
#   model_prefix: signs_char
#   model_type: CHAR
#   vocab_size: 400
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(353) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(185) LOG(INFO) Loading corpus: DataFiles/NMT_input/train.ak
# trainer_interface.cc(380) LOG(WARNING) Found too long line (14564 > 4192).
# trainer_interface.cc(382) LOG(WARNING) Too long lines are skipped in the training.
# trainer_interface.cc(383) LOG(WARNING) The maximum length can be changed with --max_sentence_length=<size> flag.
# trainer_interface.cc(409) LOG(INFO) Loaded all 4278 sentences
# trainer_interface.cc(416) LOG(INFO) Skipped 130 too long sentences.
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(430) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(539) LOG(INFO) all chars count=1292284
# trainer_interface.cc(550) LOG(INFO) Done: 99.9503% characters are covered.
# trainer_interface.cc(560) LOG(INFO) Alphabet size=324
# trainer_interface.cc(561) LOG(INFO) Final character coverage=0.999503
# trainer_interface.cc(592) LOG(INFO) Done! preprocessed 4276 sentences.
# trainer_interface.cc(687) LOG(INFO) Saving model: signs_char.model
# trainer_interface.cc(699) LOG(INFO) Saving vocabs: signs_char.vocab
# sentencepiece_trainer.cc(
# done
# done
# 178) LOG(INFO) Running command: --input=DataFiles/NMT_input/train.tr --model_type=bpe --model_prefix=transliteration_bpe --vocab_size=1000
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: DataFiles/NMT_input/train.tr
#   input_format:
#   model_prefix: transliteration_bpe
#   model_type: BPE
#   vocab_size: 1000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(353) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(185) LOG(INFO) Loading corpus: DataFiles/NMT_input/train.tr
# trainer_interface.cc(380) LOG(WARNING) Found too long line (11321 > 4192).
# trainer_interface.cc(382) LOG(WARNING) Too long lines are skipped in the training.
# trainer_interface.cc(383) LOG(WARNING) The maximum length can be changed with --max_sentence_length=<size> flag.
# trainer_interface.cc(409) LOG(INFO) Loaded all 4310 sentences
# trainer_interface.cc(416) LOG(INFO) Skipped 98 too long sentences.
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(430) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(539) LOG(INFO) all chars count=2585256
# trainer_interface.cc(550) LOG(INFO) Done: 99.9662% characters are covered.
# trainer_interface.cc(560) LOG(INFO) Alphabet size=63
# trainer_interface.cc(561) LOG(INFO) Final character coverage=0.999662
# trainer_interface.cc(592) LOG(INFO) Done! preprocessed 4310 sentences.
# trainer_interface.cc(598) LOG(INFO) Tokenizing input sentences with whitespace: 4310
# trainer_interface.cc(609) LOG(INFO) Done! 38774
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=162026 min_freq=1
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12637 size=20 all=818 active=754 piece=▁{1}
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6988 size=40 all=976 active=912 piece=MU
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4449 size=60 all=1155 active=1091 piece=URU
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3654 size=80 all=1326 active=1262 piece=▁SI
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2971 size=100 all=1452 active=1388 piece=me
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2913 min_freq=7
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2416 size=120 all=1573 active=1114 piece=MUL
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1896 size=140 all=1663 active=1204 piece=ga
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1484 size=160 all=1761 active=1302 piece=UD
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1224 size=180 all=1816 active=1357 piece=▁KUG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1026 size=200 all=1890 active=1431 piece=DUG
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1008 min_freq=15
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=852 size=220 all=1958 active=1068 piece=▁MAŠ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=766 size=240 all=1978 active=1088 piece=AMAR
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=649 size=260 all=2050 active=1160 piece=mar
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=588 size=280 all=2075 active=1185 piece=niš
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=533 size=300 all=2127 active=1237 piece=▁PA
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=530 min_freq=15
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=488 size=320 all=2163 active=1035 piece=ab
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=452 size=340 all=2191 active=1063 piece=RIN
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=408 size=360 all=2211 active=1083 piece=MUN
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=381 size=380 all=2215 active=1087 piece=SKAL
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=349 size=400 all=2223 active=1095 piece=▁gi
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=342 min_freq=13
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=325 size=420 all=2231 active=1004 piece=▁SA
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=305 size=440 all=2229 active=1002 piece=▁13
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=285 size=460 all=2231 active=1004 piece=▁GIŠ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=264 size=480 all=2246 active=1019 piece=piš
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=243 size=500 all=2249 active=1022 piece=▁dan
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=241 min_freq=10
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=230 size=520 all=2253 active=1005 piece=arba
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=217 size=540 all=2253 active=1005 piece=TIR
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=207 size=560 all=2249 active=1001 piece=▁28
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=189 size=580 all=2250 active=1002 piece=▁ṣu
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=171 size=600 all=2242 active=994 piece=he
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=171 min_freq=8
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=156 size=620 all=2239 active=996 piece=eh
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=148 size=640 all=2231 active=988 piece=▁DIŠ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=138 size=660 all=2224 active=981 piece=tak
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=129 size=680 all=2214 active=971 piece=▁dib
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=115 size=700 all=2203 active=960 piece=▁ru
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=115 min_freq=6
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=111 size=720 all=2197 active=994 piece=▁GEŠTIN
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=105 size=740 all=2203 active=1000 piece=▁aq
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=100 size=760 all=2189 active=986 piece=SUHUR
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=94 size=780 all=2186 active=983 piece=▁ah
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=91 size=800 all=2199 active=996 piece=▁sah
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=91 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=85 size=820 all=2182 active=984 piece=DAM
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=76 size=840 all=2171 active=973 piece=KUN
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=69 size=860 all=2161 active=963 piece=NUG
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=65 size=880 all=2146 active=948 piece=-0
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=63 size=900 all=2147 active=949 piece=▁ŠID
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=62 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=59 size=920 all=2137 active=991 piece=▁TUK
# trainer_interface.cc(687) LOG(INFO) Saving model: transliteration_bpe.model
# trainer_interface.cc(699) LOG(INFO) Saving vocabs: transliteration_bpe.vocab
# sentencepiece_trainer.cc
# done
# (178) LOG(INFO) Running command: --input=DataFiles/NMT_input/train.en --model_type=bpe --model_prefix=translation_bpe --vocab_size=10000
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: DataFiles/NMT_input/train.en
#   input_format:
#   model_prefix: translation_bpe
#   model_type: BPE
#   vocab_size: 10000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(353) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(185) LOG(INFO) Loading corpus: DataFiles/NMT_input/train.en
# trainer_interface.cc(380) LOG(WARNING) Found too long line (4201 > 4192).
# trainer_interface.cc(382) LOG(WARNING) Too long lines are skipped in the training.
# trainer_interface.cc(383) LOG(WARNING) The maximum length can be changed with --max_sentence_length=<size> flag.
# trainer_interface.cc(409) LOG(INFO) Loaded all 6911 sentences
# trainer_interface.cc(416) LOG(INFO) Skipped 393 too long sentences.
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(430) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(539) LOG(INFO) all chars count=6192164
# trainer_interface.cc(550) LOG(INFO) Done: 99.951% characters are covered.
# trainer_interface.cc(560) LOG(INFO) Alphabet size=100
# trainer_interface.cc(561) LOG(INFO) Final character coverage=0.99951
# trainer_interface.cc(592) LOG(INFO) Done! preprocessed 6911 sentences.
# trainer_interface.cc(598) LOG(INFO) Tokenizing input sentences with whitespace: 6911
# trainer_interface.cc(609) LOG(INFO) Done! 82426
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=139827 min_freq=48
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=34150 size=20 all=2753 active=1768 piece=▁l
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22489 size=40 all=3836 active=2851 piece=▁p
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14144 size=60 all=4797 active=3812 piece=▁A
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9438 size=80 all=5380 active=4395 piece=ss
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7518 size=100 all=6300 active=5315 piece=▁T
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7501 min_freq=573
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6431 size=120 all=7292 active=1952 piece=▁will
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5423 size=140 all=7863 active=2523 piece=00
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4860 size=160 all=8331 active=2991 piece=▁3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4234 size=180 all=8928 active=3588 piece=▁serv
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3604 size=200 all=9290 active=3950 piece=▁saao
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=3589 min_freq=514
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3229 size=220 all=9821 active=1532 piece=▁con
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2943 size=240 all=10152 active=1863 piece=lon
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2692 size=260 all=10784 active=2495 piece=ig
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2450 size=280 all=11451 active=3162 piece=▁—
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2257 size=300 all=11970 active=3681 piece=334
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2239 min_freq=461
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2079 size=320 all=12582 active=1590 piece=ef
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1891 size=340 all=12957 active=1965 piece=ubit
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1797 size=360 all=13212 active=2220 piece=ministrative
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1678 size=380 all=13652 active=2660 piece=kel
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1518 size=400 all=13991 active=2999 piece=▁lit
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1506 min_freq=396
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1463 size=420 all=14200 active=1199 piece=▁city
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=9180 all=54020 active=2870 piece=xtend
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=9200 all=54026 active=2876 piece=▁equi
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=13 min_freq=8
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=9220 all=54034 active=2709 piece=asurer
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=9240 all=54039 active=2714 piece=▁ariye
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=9260 all=54038 active=2713 piece=▁shine
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=9280 all=54030 active=2705 piece=▁argued
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=9300 all=54023 active=2698 piece=▁šagana
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=13 min_freq=8
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=9320 all=54029 active=2708 piece=▁fissure
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=9340 all=54010 active=2689 piece=▁[...]?"(
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=9360 all=54001 active=2680 piece=▁[...]...,
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=9380 all=53981 active=2660 piece=▁victoriously
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=9400 all=54034 active=2713 piece=aks
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=12 min_freq=8
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=9420 all=54112 active=2773 piece=usu
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=9440 all=54177 active=2838 piece=3949
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=9460 all=54243 active=2904 piece=hund
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=9480 all=54276 active=2937 piece=saga
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=9500 all=54307 active=2968 piece=▁Mor
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=12 min_freq=8
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=9520 all=54377 active=2785 piece=▁pos
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=9540 all=54485 active=2893 piece=23767
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=9560 all=54628 active=3036 piece=31401
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=9580 all=54743 active=3151 piece=Those
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=9600 all=54760 active=3168 piece=iture
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=12 min_freq=8
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=9620 all=54767 active=2744 piece=▁030)
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=9640 all=54760 active=2737 piece=▁pile
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=9660 all=54767 active=2744 piece=soiled
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=9680 all=54766 active=2743 piece=▁cease
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=9700 all=54753 active=2730 piece=▁parts
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=12 min_freq=8
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=9720 all=54746 active=2731 piece=panying
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=9740 all=54738 active=2723 piece=▁eighth
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=9760 all=54734 active=2719 piece=▁retain
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=9780 all=54731 active=2716 piece=▁bearing
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=9800 all=54716 active=2701 piece=▁parched
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=12 min_freq=7
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=9820 all=54697 active=2717 piece=▁extended
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=9840 all=54681 active=2701 piece=▁abandoned
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=9860 all=54662 active=2682 piece=▁disbanding
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=9880 all=54642 active=2662 piece=���[...]...[...](
# trainer_interface.cc(687) LOG(INFO) Saving model: translation_bpe.model
# trainer_interface.cc(699) LOG(INFO) Saving vocabs: translation_bpe.vocab

# %% [markdown]
# ## 2. Next I copy in and edit the paths in the rest of the file and test out the functions. These functions mainly create new files with tokenized or detokenized information.

# %%
def tokenize(model_prefix, file, should_remove_prefix=False, token_dir=TOKEN_DIR, base_dir=BASE_DIR, output_dir=TOKEN_DIR):
    sp = sentencepiece.SentencePieceProcessor()
    f = model_prefix + ".model"
    sp.load(str(token_dir / f))

    with open(base_dir / file, "r", encoding="utf8") as fin:
        data = fin.readlines()

    if should_remove_prefix:
        tokenized_data = [" ".join(sp.encode_as_pieces(line.split(": ", 1)[1])) for line in data]
    else:
        tokenized_data = [" ".join(sp.encode_as_pieces(line)) for line in data]
    #print('\n'.join(tokenized_data))

    output_file = output_dir / file
    with open(output_file, "w", encoding="utf8") as fout:
        for line in tokenized_data:
            fout.write(line + "\n")

def detokenize_atae_translated():
    sp1 = sentencepiece.SentencePieceProcessor()
    sp1.load(str(TOKEN_DIR / "transliteration_bpe.model"))

    sp2 = sentencepiece.SentencePieceProcessor()
    sp2.load(str(TOKEN_DIR / "translation_bpe.model"))

    with open(Path("DataFiles/atae_translated.txt"), "r", encoding="utf8") as fin:
        data = fin.readlines()

    detokenized_data = []
    for line in data:
        if line[0] == 'S':
            parts = line.split("\t", 1)
            detokenized_data.append(parts[0] + "\t" + sp1.decode_pieces(parts[1].split(" ")))
        elif line[0] == 'H' or line[0] == 'D':
            parts = line.split("\t", 2)
            detokenized_data.append(parts[0] + "\t" + parts[1] + "\t" + sp2.decode_pieces(parts[2].split(" ")))
        else:
            detokenized_data.append(line)

    with open(Path("DataFiles/atae_translated_detokenized.txt"), "w", encoding="utf8") as fout:
        for line in detokenized_data:
            fout.write(line)

def detokenize_best_run_test_data_translated(only_core_data):
    sp1 = sentencepiece.SentencePieceProcessor()
    sp1.load(str(TOKEN_DIR / "transliteration_bpe.model"))

    sp2 = sentencepiece.SentencePieceProcessor()
    sp2.load(str(TOKEN_DIR / "translation_bpe.model"))

    with open(Path("DataFiles/best_run_test_data_translated.txt"), "r", encoding="utf8") as fin:
        data = fin.readlines()

    detokenized_data = []
    for line in data:
        if line[0] == 'S':
            if not only_core_data:
                parts = line.split("\t", 1)
                detokenized_data.append(parts[0] + "\t" + sp1.decode_pieces(parts[1].split(" ")).replace("_", " "))
        elif line[0] == 'T':
            parts = line.split("\t", 1)
            if only_core_data:
                detokenized_data.append("<gold>: " + sp2.decode_pieces(parts[1].split(" ")).replace("_", " "))
            else:
                detokenized_data.append(parts[0] + "\t" + sp2.decode_pieces(parts[1].split(" ")).replace("_", " "))
        elif line[0] == 'H' or line[0] == 'D':
            parts = line.split("\t", 2)
            if only_core_data:
                if line[0] == 'H':
                    detokenized_data.append("<predicted>: " + sp2.decode_pieces(parts[2].split(" ")).replace("_", " ") + "\n")
            else:
                detokenized_data.append(parts[0] + "\t" + parts[1] + "\t" + sp2.decode_pieces(parts[2].split(" ")).replace("_", " "))
        else:
            if not only_core_data:
                detokenized_data.append(line)

    with open(Path("DataFiles/best_run_test_data_translated_detokenized.txt"), "w", encoding="utf8") as fout:
        for line in detokenized_data:
            fout.write(line)


def run_tokenizer():
    # TODO: Compare signs_chars to signs_bpe
    tokenize("signs_char", TRAIN_AK)
    tokenize("signs_char", VALID_AK)
    tokenize("signs_char", TEST_AK)

    tokenize("transliteration_bpe", TRAIN_TR)
    tokenize("transliteration_bpe", VALID_TR)
    tokenize("transliteration_bpe", TEST_TR)

    tokenize("translation_bpe", TRAIN_EN)
    tokenize("translation_bpe", VALID_EN)
    tokenize("translation_bpe", TEST_EN)


def tokenize_transliteration_for_translation():
    tokenize("transliteration_bpe", FOR_TRANSLATION_TR, True)


def main():
    train_tokenizer()
    run_tokenizer()
    # tokenize_transliteration_for_translation()
    # detokenize_atae_translated()
    # detokenize_best_run_test_data_translated(True)

# %% [markdown]
# `run_tokenizer()` works properly (runs tokenize 9 times and updates the corresponding files in nmt_input/not_divided_by_three_dots/tokenization)

# %%
run_tokenizer()

# %% [markdown]
# detokenize_atae_translated() updates the detokenize_atae_translated.txt file

# %%
detokenize_atae_translated() #had to change the '../atae_translated.txt' because it can't find the path this way

# %%
detokenize_best_run_test_data_translated(True) # also works- the input true means only the core data is translated

# %% [markdown]
# Next I'm just running a quick test to make sure the code works by populating an empty file I randomly called "requirements" + this worked and filled the file.

# %%
def detokenize_atae_translated_test():
    sp1 = sentencepiece.SentencePieceProcessor()
    sp1.load(str(TOKEN_DIR / "transliteration_bpe.model"))

    sp2 = sentencepiece.SentencePieceProcessor()
    sp2.load(str(TOKEN_DIR / "translation_bpe.model"))

    with open(Path("DataFiles/atae_translated.txt"), "r", encoding="utf8") as fin:
        data = fin.readlines()

    detokenized_data = []
    for line in data:
        if line[0] == 'S':
            parts = line.split("\t", 1)
            detokenized_data.append(parts[0] + "\t" + sp1.decode_pieces(parts[1].split(" ")))
        elif line[0] == 'H' or line[0] == 'D':
            parts = line.split("\t", 2)
            detokenized_data.append(parts[0] + "\t" + parts[1] + "\t" + sp2.decode_pieces(parts[2].split(" ")))
        else:
            detokenized_data.append(line)

    with open(Path("DataFiles/requirements.txt"), "w", encoding="utf8") as fout:
        for line in detokenized_data:
            fout.write(line)

# %%
detokenize_atae_translated_test()

# %% [markdown]
# #III. Paramaterization:

# %% [markdown]
# The below is the code from Akkademia/run_slurm.sh with some edited paths and translated to python. Currently will create directories in your 'Files' tab (not in your drive), but the path for OUT_DIR can easily be edited so that the directories are sent into Akkademia-master. For example, you could change the code to something like `OUT_DIR = f"/content/drive/MyDrive/Akkademia-master/result.LR_{LR}.MAX_TOKENS_{MAX_TOKENS}"` if you wanted the directories to be added to Akkademia-master.

# %%
import os

def run(LR, MAX_TOKENS):
    OUT_DIR = f"result.LR_{LR}.MAX_TOKENS_{MAX_TOKENS}"
    os.makedirs(OUT_DIR, exist_ok=True)

    with open(f"{OUT_DIR}/akkadian_fairseq.slurm", "w") as slurm_file:
        with open("DataFiles/akkadian_fairseq.template", "r") as template_file: # edited path to template file
            slurm_template = template_file.read()
            slurm_template = slurm_template.replace("LR_PLACEHOLDER", str(LR))
            slurm_template = slurm_template.replace("MAX_TOKENS_PLACEHOLDER", str(MAX_TOKENS))
            slurm_file.write(slurm_template)
    print(OUT_DIR)
    os.chdir(OUT_DIR)
    os.system("sbatch akkadian_fairseq.slurm")
    os.chdir("..")

for LR in [0.05, 0.1]:
    for MAX_TOKENS in [4000, 8000]:
      run(LR, MAX_TOKENS)
# Out:
# result.LR_0.05.MAX_TOKENS_4000
# result.LR_0.05.MAX_TOKENS_8000
# result.LR_0.1.MAX_TOKENS_4000
# result.LR_0.1.MAX_TOKENS_8000
# sh: sbatch: command not found
# sh: sbatch: command not found
# sh: sbatch: command not found
# sh: sbatch: command not found

# %% [markdown]
# Some concerns might be that once you make each of the fairseq.slurm files, they are also in linux/bash (?) so I dont think you can run them in the notebooks either. Might need to change some of the files so that the akkadian_fairseq.sh file will run properly from the notebook in the Translation step.

# %% [markdown]
# #IV. Translation
#
# In this section we will prepare some texts for machine translation. The following format will allow for an iterative approach to the data input:
#
# |id_text|lang|transliteration|cuneiform|translation|
# |-------|----|:--------------|:--------|:----------|
# |P123456|sux|1 ma-na ku3.babbar| 𒁹	𒈠𒈾 𒆬𒌓| (empty)|
#
# And get the desired result:
#
# |id_text|lang|transliteration|cuneiform|translation|
# |-------|----|:--------------|:--------|:----------|
# |P123456|sux|1 ma-na ku3.babbar| 𒁹	𒈠𒈾 𒆬𒌓| 1 mina silver|

# %%
# !git clone https://github.com/gaigutherz/Akkademia.git
# !cd Akkademia/trans_result.LR_0.1.MAX_TOKENS_4000 && cat checkpoint_best.pt.* > checkpoint_best.pt
# !cd Akkademia/not_divided_by_three_dots_result.LR_0.1.MAX_TOKENS_4000 && cat checkpoint_best.pt.* > checkpoint_best.pt
# !pip install sentencepiece
# !git clone https://github.com/pytorch/fairseq
# !cd fairseq && pip install ./
# !chmod +x fairseq/fairseq_cli/interactive.py
# !sed -i 's/#!\/usr\/bin\/env python3 -u/#!\/usr\/bin\/env python3/g' fairseq/fairseq_cli/interactive.py
# Out:
# Cloning into 'Akkademia'...
# remote: Enumerating objects: 10676, done.
# remote: Counting objects: 100% (170/170), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 10676 (delta 107), reused 152 (delta 93), pack-reused 10506 (from 1)
# Receiving objects: 100% (10676/10676), 3.28 GiB | 4.04 MiB/s, done.
# Resolving deltas: 100% (9878/9878), done.
# Updating files: 100% (7381/7381), done.
# Requirement already satisfied: sentencepiece in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.2.0)
# Cloning into 'fairseq'...
# remote: Enumerating objects: 35209, done.
# remote: Counting objects: 100% (126/126), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 35209 (delta 68), reused 88 (delta 52), pack-reused 35083 (from 1)
# Receiving objects: 100% (35209/35209), 25.23 MiB | 4.13 MiB/s, done.
# Resolving deltas: 100% (25558/25558), done.
# Processing /Users/christiankarren/Desktop/research_repo/FGCuneiform_MachineTranslation/fairseq
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: cffi in /Users/christiankarren/Library/Python/3.11/lib/python/site-packages (from fairseq==0.12.2) (1.17.0)
# Collecting cython (from fairseq==0.12.2)
#   Using cached Cython-3.0.11-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting hydra-core<1.1,>=1.0.7 (from fairseq==0.12.2)
#   Downloading hydra_core-1.0.7-py3-none-any.whl.metadata (3.7 kB)
# Collecting omegaconf<2.1 (from fairseq==0.12.2)
#   Downloading omegaconf-2.0.6-py3-none-any.whl.metadata (3.0 kB)
# WARNING: Ignoring version 2.0.6 of omegaconf since it has invalid metadata:
# Requested omegaconf<2.1 from https://files.pythonhosted.org/packages/d0/eb/9d63ce09dd8aa85767c65668d5414958ea29648a0eec80a4a7d311ec2684/omegaconf-2.0.6-py3-none-any.whl (from fairseq==0.12.2) has invalid metadata: .* suffix can only be used with `==` or `!=` operators
#     PyYAML (>=5.1.*)
#             ~~~~~~^
# Please use pip<24.1 if you need to use this version.
#   Downloading omegaconf-2.0.5-py3-none-any.whl.metadata (3.0 kB)
# WARNING: Ignoring version 2.0.5 of omegaconf since it has invalid metadata:
# Requested omegaconf<2.1 from https://files.pythonhosted.org/packages/e5/f6/043b6d255dd6fbf2025110cea35b87f4c5100a181681d8eab496269f0d5b/omegaconf-2.0.5-py3-none-any.whl (from fairseq==0.12.2) has invalid metadata: .* suffix can only be used with `==` or `!=` operators
#     PyYAML (>=5.1.*)
#             ~~~~~~^
# Please use pip<24.1 if you need to use this version.
#   Downloading omegaconf-2.0.4-py3-none-any.whl.metadata (3.0 kB)
# WARNING: Ignoring version 2.0.4 of omegaconf since it has invalid metadata:
# Requested omegaconf<2.1 from https://files.pythonhosted.org/packages/92/b1/4f3023143436f12c98bab53f0b3db617bd18a7d223627d5030e13a7b4fc2/omegaconf-2.0.4-py3-none-any.whl (from fairseq==0.12.2) has invalid metadata: .* suffix can only be used with `==` or `!=` operators
#     PyYAML (>=5.1.*)
#             ~~~~~~^
# Please use pip<24.1 if you need to use this version.
#   Downloading omegaconf-2.0.3-py3-none-any.whl.metadata (3.0 kB)
# WARNING: Ignoring version 2.0.3 of omegaconf since it has invalid metadata:
# Requested omegaconf<2.1 from https://files.pythonhosted.org/packages/29/08/a88210c2c1aa0a3f65f05d8a6c98939ccb84b6fb982aa6567dec4e6773f9/omegaconf-2.0.3-py3-none-any.whl (from fairseq==0.12.2) has invalid metadata: .* suffix can only be used with `==` or `!=` operators
#     PyYAML (>=5.1.*)
#             ~~~~~~^
# Please use pip<24.1 if you need to use this version.
#   Downloading omegaconf-2.0.2-py3-none-any.whl.metadata (3.0 kB)
# WARNING: Ignoring version 2.0.2 of omegaconf since it has invalid metadata:
# Requested omegaconf<2.1 from https://files.pythonhosted.org/packages/72/fe/f8d162aa059fb4f327fd75144dd69aa7e8acbb6d8d37013e4638c8490e0b/omegaconf-2.0.2-py3-none-any.whl (from fairseq==0.12.2) has invalid metadata: .* suffix can only be used with `==` or `!=` operators
#     PyYAML (>=5.1.*)
#             ~~~~~~^
# Please use pip<24.1 if you need to use this version.
#   Downloading omegaconf-2.0.1-py3-none-any.whl.metadata (3.0 kB)
# WARNING: Ignoring version 2.0.1 of omegaconf since it has invalid metadata:
# Requested omegaconf<2.1 from https://files.pythonhosted.org/packages/86/ec/605805e60abdb025b06664d107335031bb8ebdc52e0a90bdbad6a7130279/omegaconf-2.0.1-py3-none-any.whl (from fairseq==0.12.2) has invalid metadata: .* suffix can only be used with `==` or `!=` operators
#     PyYAML (>=5.1.*)
#             ~~~~~~^
# Please use pip<24.1 if you need to use this version.
#   Downloading omegaconf-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.21.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from fairseq==0.12.2) (1.25.2)
# Collecting regex (from fairseq==0.12.2)
#   Downloading regex-2024.7.24-cp311-cp311-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting sacrebleu>=1.4.12 (from fairseq==0.12.2)
#   Downloading sacrebleu-2.4.3-py3-none-any.whl.metadata (51 kB)
# Collecting torch>=1.13 (from fairseq==0.12.2)
#   Using cached torch-2.4.0-cp311-none-macosx_11_0_arm64.whl.metadata (26 kB)
# Collecting tqdm (from fairseq==0.12.2)
#   Downloading tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Collecting bitarray (from fairseq==0.12.2)
#   Downloading bitarray-2.9.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (34 kB)
# Collecting torchaudio>=0.8.0 (from fairseq==0.12.2)
#   Downloading torchaudio-2.4.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from fairseq==0.12.2) (1.5.1)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from fairseq==0.12.2) (24.1)
# Collecting omegaconf<2.1 (from fairseq==0.12.2)
#   Using cached omegaconf-2.0.6-py3-none-any.whl.metadata (3.0 kB)
# WARNING: Ignoring version 2.0.6 of omegaconf since it has invalid metadata:
# Requested omegaconf<2.1 from https://files.pythonhosted.org/packages/d0/eb/9d63ce09dd8aa85767c65668d5414958ea29648a0eec80a4a7d311ec2684/omegaconf-2.0.6-py3-none-any.whl (from fairseq==0.12.2) has invalid metadata: .* suffix can only be used with `==` or `!=` operators
#     PyYAML (>=5.1.*)
#             ~~~~~~^
# Please use pip<24.1 if you need to use this version.
#   Using cached omegaconf-2.0.5-py3-none-any.whl.metadata (3.0 kB)
# WARNING: Ignoring version 2.0.5 of omegaconf since it has invalid metadata:
# Requested omegaconf<2.1 from https://files.pythonhosted.org/packages/e5/f6/043b6d255dd6fbf2025110cea35b87f4c5100a181681d8eab496269f0d5b/omegaconf-2.0.5-py3-none-any.whl (from fairseq==0.12.2) has invalid metadata: .* suffix can only be used with `==` or `!=` operators
#     PyYAML (>=5.1.*)
#             ~~~~~~^
# Please use pip<24.1 if you need to use this version.
# INFO: pip is looking at multiple versions of hydra-core to determine which version is compatible with other requirements. This could take a while.
# ERROR: Cannot install fairseq and fairseq==0.12.2 because these package versions have conflicting dependencies.
#
# The conflict is caused by:
#     fairseq 0.12.2 depends on omegaconf<2.1
#     hydra-core 1.0.7 depends on omegaconf<2.1 and >=2.0.5
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip to attempt to solve the dependency conflict
#
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/topics/dependency-resolution/#dealing-with-dependency-conflicts
# sed: 1: "fairseq/fairseq_cli/int ...": invalid command code f

# %% [markdown]
# ## 4.1 Load the Models

# %%
TRANSLITERATION_MODEL_PATH = "DataFiles/NMT_input/tokenization/transliteration_bpe.model"
TRANSLATION_MODEL_PATH = "DataFiles/NMT_input/tokenization/translation_bpe.model"

# %%
def translation(line):
    if len(line) < 1:
        return False

def translate_transliteration(sentence):
    tmp_file = "transliteration.tmp"
    with open(tmp_file, "w") as f:
        f.write(sentence)
    print(TRANSLATION_MODEL_PATH)
    raw_result = translate_transliteration_base(tmp_file, True).stdout
    os.remove(tmp_file)

    output = ""
    print(TRANSLATION_MODEL_PATH)
    for line in raw_result.decode().split('\n'):
        if translation(line):
            output += detokenize_translation(line, TRANSLATION_MODEL_PATH)

    return output


#if __name__ == '__main__':
    # sentence = input("Please enter a transliteration sentence for translation\n")
   # print(translate_transliteration(sentence))

# %%
ls DataFiles/NMT_input/tokenization/
# Out:
# CODE_OF_CONDUCT.md         setup.py
# CONTRIBUTING.md            signs_char.model
# LICENSE                    signs_char.vocab
# MANIFEST.in                t2e_translation_memory.en
# README.md                  test.ak
# RELEASE.md                 test.en
# docs/                      test.tr
# examples/                  tests/
# fairseq/                   train.ak
# fairseq_cli/               train.en
# fg.csv                     train.py
# for_translation.tr         train.tr
# hubconf.py                 translation_bpe.model
# hydra_plugins/             translation_bpe.vocab
# my_signs_char.model        transliteration_bpe.model
# my_signs_char.vocab        transliteration_bpe.vocab
# pyproject.toml             valid.ak
# release_utils.py           valid.en
# scripts/                   valid.tr
# setup.cfg

# %% [markdown]
# #V. Final Assessment of the Translation
#
# Here we use the outcome of the text / train / valid files to determine how well the Machine Translation worked for this group of texts.
